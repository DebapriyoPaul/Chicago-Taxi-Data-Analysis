# %% [markdown]
# #Data Exploration and Prediction on four years data

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import numpy as np
import pandas as pd
from dateutil import parser
from google.colab import files
# !pip install geopandas
import geopandas as gpd
# !pip install Pysal
# !pip install fiona
import fiona
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# #Data Loading to SQL database
#
# The data is first loaded as chunks of size 1000 in python and appended to a SQLlite3 database. Thereafter, the data is queried to obtain month-wise info which are then stored as CSVs

# %%
chunksize = 1000
m = 0
j = 1

for df in pd.read_csv('C:/Debapriyo Paul/Course Documents/TAMIDS competition/2016.csv', chunksize=chunksize, iterator=True):
    m+=1 
    if m % 1000 == 0:
        print(m)

# %%
chunksize = 1000
m = 0
#j = 1

for df in pd.read_csv('C:/Debapriyo Paul/Course Documents/TAMIDS competition/2016.csv', chunksize=chunksize, iterator=True):
    temp = pd.DataFrame(df)
    temp['start timestamp'] = temp['Trip Start Timestamp'].apply(parser.parse)
    temp['month'] = temp['start timestamp'].map(lambda x: x.month)
    jan = temp[temp['month'] == 1]
    num_month = list(range(1,13))
    months = ['jan_16', 'feb_16', 'mar_16', 'apr_16', 'may_16', 'june_16', 'jul_16', 'aug_16', 'sept_16', 'oct_16', 'nov_16', 'dec_16']
    for i,k in zip(num_month, months):
        l = temp[temp['month'] == i]
        #l.index += j
        l.to_sql(k, csv_database, if_exists='append', index = False)
        #j = l.index[-1] + 1
        #print(j)
    m+=1      
    
    if m % 1000 == 0:
        print(m)

# %%
months = ['jan_16', 'feb_16', 'mar_16', 'apr_16', 'may_16', 'june_16', 'jul_16', 'aug_16', 'sept_16', 'oct_16', 'nov_16', 'dec_16']
for i in months:
    temp  = pd.read_sql_query('SELECT * FROM ' + str(i), csv_database)
    temp.to_csv(str(i) + '.csv')

# %%
chunksize = 1000
m = 0
j = 1

for df in pd.read_csv('C:/Debapriyo Paul/Course Documents/TAMIDS competition/2015.csv', chunksize=chunksize, iterator=True):
    m+=1 
    if m % 1000 == 0:
        print(m)

# %%
chunksize = 1000
m = 0
#j = 1

for df in pd.read_csv('C:/Debapriyo Paul/Course Documents/TAMIDS competition/2015.csv', chunksize=chunksize, iterator=True):
    temp = pd.DataFrame(df)
    temp['start timestamp'] = temp['Trip Start Timestamp'].apply(parser.parse)
    temp['month'] = temp['start timestamp'].map(lambda x: x.month)
    jan = temp[temp['month'] == 1]
    num_month = list(range(1,13))
    months = ['jan_15', 'feb_15', 'mar_15', 'apr_15', 'may_15', 'june_15', 'jul_15', 'aug_15', 'sept_15', 'oct_15', 'nov_15', 'dec_15']
    for i,k in zip(num_month, months):
        l = temp[temp['month'] == i]
        #l.index += j
        l.to_sql(k, csv_database, if_exists='append', index = False)
        #j = l.index[-1] + 1
        #print(j)
    m+=1      
    
    if m % 1000 == 0:
        print(m)

# %%
months = ['jan_15', 'feb_15', 'mar_15', 'apr_15', 'may_15', 'june_15', 'jul_15', 'aug_15', 'sept_15', 'oct_15', 'nov_15', 'dec_15']
for i in months:
    temp  = pd.read_sql_query('SELECT * FROM ' + str(i), csv_database)
    temp.to_csv(str(i) + '.csv')

# %%
chunksize = 1000
m = 0
j = 1

for df in pd.read_csv('C:/Debapriyo Paul/Course Documents/TAMIDS competition/2014.csv', chunksize=chunksize, iterator=True):
    m+=1 
    if m % 1000 == 0:
        print(m)

# %%
chunksize = 1000
m = 0
#j = 1

for df in pd.read_csv('C:/Debapriyo Paul/Course Documents/TAMIDS competition/2014.csv', chunksize=chunksize, iterator=True):
    temp = pd.DataFrame(df)
    temp['start timestamp'] = temp['Trip Start Timestamp'].apply(parser.parse)
    temp['month'] = temp['start timestamp'].map(lambda x: x.month)
    jan = temp[temp['month'] == 1]
    num_month = list(range(1,13))
    months = ['jan_14', 'feb_14', 'mar_14', 'apr_14', 'may_14', 'june_14', 'jul_14', 'aug_14', 'sept_14', 'oct_14', 'nov_14', 'dec_14']
    for i,k in zip(num_month, months):
        l = temp[temp['month'] == i]
        #l.index += j
        l.to_sql(k, csv_database, if_exists='append', index = False)
        #j = l.index[-1] + 1
        #print(j)
    m+=1      
    
    if m % 1000 == 0:
        print(m)

# %%
months = ['jan_14', 'feb_14', 'mar_14', 'apr_14', 'may_14', 'june_14', 'jul_14', 'aug_14', 'sept_14', 'oct_14', 'nov_14', 'dec_14']
for i in months:
    temp  = pd.read_sql_query('SELECT * FROM ' + str(i), csv_database)
    temp.to_csv(str(i) + '.csv')

# %%
chunksize = 1000
m = 0
j = 1

for df in pd.read_csv('C:/Debapriyo Paul/Course Documents/TAMIDS competition/2013.csv', chunksize=chunksize, iterator=True):
    m+=1 
    if m % 1000 == 0:
        print(m)

# %%
chunksize = 1000
m = 0
#j = 1

for df in pd.read_csv('C:/Debapriyo Paul/Course Documents/TAMIDS competition/2013.csv', chunksize=chunksize, iterator=True):
    temp = pd.DataFrame(df)
    temp['start timestamp'] = temp['Trip Start Timestamp'].apply(parser.parse)
    temp['month'] = temp['start timestamp'].map(lambda x: x.month)
    jan = temp[temp['month'] == 1]
    num_month = list(range(1,13))
    months = ['jan_13', 'feb_13', 'mar_13', 'apr_13', 'may_13', 'june_13', 'jul_13', 'aug_13', 'sept_13', 'oct_13', 'nov_13', 'dec_13']
    for i,k in zip(num_month, months):
        l = temp[temp['month'] == i]
        #l.index += j
        l.to_sql(k, csv_database, if_exists='append', index = False)
        #j = l.index[-1] + 1
        #print(j)
    m+=1      
    
    if m % 1000 == 0:
        print(m)

# %%
months = ['jan_13', 'feb_13', 'mar_13', 'apr_13', 'may_13', 'june_13', 'jul_13', 'aug_13', 'sept_13', 'oct_13', 'nov_13', 'dec_13']
for i in months:
    temp  = pd.read_sql_query('SELECT * FROM ' + str(i), csv_database)
    temp.to_csv(str(i) + '.csv')

# %% [markdown]
# #Data Preprocessing
# The Data preprocessing stage is shown for on particular month only i.e January of 2016. This analysis is therafter repeated for each month.

# %%
downloaded = drive.CreateFile({'id':'1200gLP2GHumrgfnCiQwsm-kJG4S9d1O6'}) 
downloaded.GetContentFile('jan_16.csv')

# %%
from dateutil import parser

# %% [markdown]
# Multiple aspects were covered during the data cleaning and preprocessing stage-
#
# 1. Eliminating null values for specific columns
# 2. Eliminating trips with greater than 500 miles distance
# 3. Eliminating trips with greater than 12 hours duration
# 4. Converting 'Payment Types' to categorical variables
# 5. Forcing every trip with Cash payment type to have zero tips since cash tips are not recorded
# 6. Forcing minimum trip fare to be greater than 3.25 Dollars- the minimum fare for hailing a taxi in Chicago and lesser than 1000 Dollars
# 7. Eliminating redundant columns like the unconverted timestamps and 'O'Hare Community area' column

# %%
df = df[pd.isnull(df['Trip Start Timestamp']) == 0]
df = df[pd.isnull(df['Trip End Timestamp']) == 0]
df = df[pd.isnull(df['Taxi ID']) == 0] 
df = df[pd.isnull(df['Pickup Community Area']) == 0] 
df = df[pd.isnull(df['Dropoff Community Area']) == 0] 
df = df[df['Trip Miles'] < 500]

# %%
df['start timestamp'] = df['Trip Start Timestamp'].apply(parser.parse)
df['end timestamp'] = df['Trip End Timestamp'].apply(parser.parse)
df['DayName'] = df['end timestamp'].dt.weekday_name
df['Fare'] = df['Fare'].str.strip('$').apply(float)
df['Tips'] = df['Tips'].str.strip('$').apply(float)
df['Tolls'] = df['Tolls'].str.strip('$').apply(float)
df['Extras'] = df['Extras'].str.strip('$').apply(float)
df['Trip Total'] = df['Trip Total'].str.strip('$').apply(float)

# %%
df.loc[df['Payment Type'] == 'Cash', 'Tips'] = 0.0

# %%
df.loc[df['Payment Type'] == 'Cash', 'Payment Type'] = 1
df.loc[df['Payment Type'] == 'Credit Card', 'Payment Type'] = 0
df.loc[df['Payment Type'] == 'Unknown', 'Payment Type'] = 2
df.loc[df['Payment Type'] == 'Dispute', 'Payment Type'] = 3
df.loc[df['Payment Type'] == 'No Charge', 'Payment Type'] = 4

# %%
df = df[(df['Fare']>3.25) & (df['Fare']<1000)]  #Assuming min fare = 3.25 and discurding fares more than 1000
df = df[df['Trip Seconds'] <= (12*60*60)]

del df['Trip ID']
del df['Trip Start Timestamp']
del df['Trip End Timestamp']
del df['Pickup O\'Hare Community Area']
del df['Pickup Centroid Location']

# %%
df = df.drop(df.columns[[19]], axis=1)
print(np.shape(df))

# %% [markdown]
# #Data Exploration
# Exploring the distribution of the companies with respect to the Chicago taxi industry. To determine this, the yearly data from 2013 to 2016 was loaded concurrently.
#
# First we looked into the distribution of taxi rides over the course of four years from 2013 to 2016.

# %%
downloaded = drive.CreateFile({'id':'1UQ1YKFcHbMW6y_XB6UZrGnNzkqwUUuy_'}) 
downloaded.GetContentFile('Data_16') 
d16 = pd.read_csv('Data_16')
downloaded = drive.CreateFile({'id':'1ICY28mhiCgNUhRup7onq9_0mhVShAhwB'}) 
downloaded.GetContentFile('Data_2015') 
d15 = pd.read_csv('Data_2015')
downloaded = drive.CreateFile({'id':'1zpczk7IzxGn18kT8McTPlAv0tV5xAaij'}) 
downloaded.GetContentFile('Data_2013') 
d13 = pd.read_csv('Data_2013')
downloaded = drive.CreateFile({'id':'10jRZGv5REwsOwDnlUNZH8kfWlbfhAQq6'}) 
downloaded.GetContentFile('Data_14.csv') 
d14 = pd.read_csv('Data_14.csv')

# %%
a13 = d13.groupby(['month', 'Company']).agg({'Trip Total_sum':np.sum})
a13.columns = ["".join(x) for x in a13.columns.ravel()]

a14 = d14.groupby(['month', 'Company']).agg({'Trip Total_sum':np.sum})
a14.columns = ["".join(x) for x in a14.columns.ravel()]

a15 = d15.groupby(['month', 'Company']).agg({'Trip Total_sum':np.sum})
a15.columns = ["".join(x) for x in a15.columns.ravel()]

a16 = d16.groupby(['month', 'Company']).agg({'Trip Total_sum':np.sum})
a16.columns = ["".join(x) for x in a16.columns.ravel()]

# %%
d13['Year'] = 2013
d14['Year'] = 2014
d15['Year'] = 2015
d16['Year'] = 2016
df1=pd.concat([d13,d14,d15,d16])

# %%
a1 = df1.groupby(['mcount', 'Company']).agg({'Trip Total_sum':np.sum})
a1.columns = ["".join(x) for x in a1.columns.ravel()]
a1 = a1.reset_index()
a1.mcount = a1.mcount.astype(int)
a1['avgrev'] = a1['Trip Total_sum'][a1.m]

# %%
a_new.plot('month1','Trip Total_count', figsize = (20,10))
plt.savefig('tripoveryear.png')
from google.colab import files
files.download( "tripoveryear.png")

# %% [markdown]
# Plot of average fare (total fare each month divided by total rides each month) over the years (M shaped cyclical trend)

# %%
e13= d13.groupby(['month']).agg({'Trip Total_sum': sum,'Trip Total_count':sum}).reset_index()
e13['year']=2013
e13['fare'] = e13['Trip Total_sum']/e13['Trip Total_count']

# %%
e14 = d14.groupby(['month']).agg({'Trip Total_sum': sum,'Trip Total_count':sum}).reset_index()
e14['year']=2014
e14['fare'] = e14['Trip Total_sum']/e14['Trip Total_count']

# %%
e15 = d15.groupby(['month']).agg({'Trip Total_sum': sum,'Trip Total_count':sum}).reset_index()
e15['year']=2015
e15['fare'] = e15['Trip Total_sum']/e15['Trip Total_count']

# %%
e16 = d16.groupby(['month']).agg({'Trip Total_sum': sum,'Trip Total_count':sum}).reset_index()
e16['year']=2016
e16['fare'] = e16['Trip Total_sum']/e16['Trip Total_count']

# %%
e = pd.concat([e13,e14,e15,e16])

# %%
e.loc[e.year == 2013, 'mcount'] = e.loc[e.year == 2013]['month']
e.loc[e.year == 2014, 'mcount'] = e.loc[e.year == 2014]['month'] +12
e.loc[e.year == 2015, 'mcount'] = e.loc[e.year == 2015]['month'] +24
e.loc[e.year == 2016, 'mcount'] = e.loc[e.year == 2016]['month'] +36

# %%
e.mcount = e.mcount.astype(int)

# %%
plt.style.use('fivethirtyeight')
bounds = [2013,2014,2015,2016,2017]
colors = ["darkorchid", "crimson", "limegreen", "gold"]
cmap = mpl.colors.ListedColormap(colors)
norm = mpl.colors.BoundaryNorm(bounds, len(colors))
fig, ax = plt.subplots()
ax.plot(e.mcount,e.fare,zorder =1,color ='k', linewidth =1)
sc = ax.scatter(e.mcount, e.fare, c=e.year.values, cmap=cmap, norm=norm, zorder =2)
fig.colorbar(sc, spacing="proportional")
plt.xticks([],[])
plt.ylabel('Average Fare $')
plt.show()
from google.colab import files
#plt.savefig("abc.png")
#files.download("abc.png")

# %% [markdown]
# Comparison of Company-wise market share over the years

# %%
#company wise revenue of 2013
c13 = d13.groupby(['Company']).agg({'Trip Total_sum': sum, 'Trip Seconds_sum': sum, 'Trip Miles_sum':sum, 'Trip Total_count':sum})
c13.columns = ["".join(x) for x in c13.columns.ravel()]
c13 = c13.reset_index()
c13['Revpercent'] = c13['Trip Total_sum']/c13['Trip Total_sum'].sum()*100
c13['fare'] = c13['Trip Total_sum']/(c13['Trip Miles_sum'])
c13 = c13.sort_values(by = ['Trip Total_sum'], ascending = False)

# %%
#company wise revenue of 2014
c14 = d14.groupby(['Company']).agg({'Trip Total_sum': sum, 'Trip Seconds_sum': sum, 'Trip Miles_sum':sum, 'Trip Total_count':sum})
c14.columns = ["".join(x) for x in c14.columns.ravel()]
c14 = c14.reset_index()
c14['Revpercent'] = c14['Trip Total_sum']/c14['Trip Total_sum'].sum()*100
c14['fare'] = c14['Trip Total_sum']/(c14['Trip Miles_sum'])
c14 = c14.sort_values(by = ['Trip Total_sum'], ascending = False)

# %%
#company wise revenue of 2015
c15 = d15.groupby(['Company']).agg({'Trip Total_sum': sum, 'Trip Seconds_sum': sum, 'Trip Miles_sum':sum, 'Trip Total_count':sum})
c15.columns = ["".join(x) for x in c15.columns.ravel()]
c15 = c15.reset_index()
c15['Revpercent'] = c15['Trip Total_sum']/c15['Trip Total_sum'].sum()*100
c15['fare'] = c15['Trip Total_sum']/(c15['Trip Miles_sum'])
c15 = c15.sort_values(by = ['Trip Total_sum'], ascending = False)

# %%
#company wise revenue of 2016
c16 = d16.groupby(['Company']).agg({'Trip Total_sum': sum, 'Trip Seconds_sum': sum, 'Trip Miles_sum':sum, 'Trip Total_count':sum})
c16.columns = ["".join(x) for x in c16.columns.ravel()]
c16 = c16.reset_index()
c16['Revpercent'] = c16['Trip Total_sum']/c16['Trip Total_sum'].sum()*100
c16['fare'] = c16['Trip Total_sum']/(c16['Trip Miles_sum'])
c16 = c16.sort_values(by = ['Trip Total_sum'], ascending = False)

# %%
c13trim = c13.iloc[:5, [0,1]]
c13trim.loc[len(c13trim),:] = ['Others', c13.iloc[6:,1].sum()]
c13trim['year'] = 2013
c14trim = c14.iloc[:5, [0,1]]
c14trim.loc[len(c14trim),:] = ['Others', c14.iloc[6:,1].sum()]
c14trim['year'] = 2014
c15trim = c15.iloc[:5, [0,1]]
c15trim.loc[len(c15trim),:] = ['Others', c15.iloc[6:,1].sum()]
c15trim['year'] = 2015
c16trim = c16.iloc[:5, [0,1]]
c16trim.loc[len(c16trim),:] = ['Others', c16.iloc[6:,1].sum()]
c16trim['year'] = 2016

# %%
ctrim = pd.concat([c13trim, c14trim, c15trim, c16trim])

# %% [markdown]
# This plot below shows the distribution of company-wise revenues over the year. As evident from the plot, the overall industry shows a consistent decreasing trend even though the revenue increased a bit from 2013 to 2014. Taxi Affiliation Services have the lion's share of the market, but its share dropped by over 8% from 2014 to 2016. A reason behind this might be the ever-increasing share of 'Other' groups, smaller taxi companies, implying that the industry is becoming more and more fragmented.

# %%
pivot_ctrim = ctrim.pivot(index='year', columns='Company', values='Trip Total_sum')
pivot_ctrim.plot.bar(stacked =True, figsize=(15,8))
#from google.colab import files

plt.savefig("abc.png")
files.download("abc.png")

# %% [markdown]
# #Predictive Analytics on 2016 data

# %%
downloaded = drive.CreateFile({'id':'1200gLP2GHumrgfnCiQwsm-kJG4S9d1O6'}) 
downloaded.GetContentFile('Data_16.csv') 
df = pd.read_csv('Data_16.csv')

# %%
df = df[pd.isnull(df['Trip Start Timestamp']) == 0]
df = df[pd.isnull(df['Trip End Timestamp']) == 0]
df = df[pd.isnull(df['Taxi ID']) == 0] 
df = df[pd.isnull(df['Pickup Community Area']) == 0] 
df = df[pd.isnull(df['Dropoff Community Area']) == 0] 
df = df[df['Trip Miles'] < 500]

# %%
df['start timestamp'] = df['Trip Start Timestamp'].apply(parser.parse)
df['end timestamp'] = df['Trip End Timestamp'].apply(parser.parse)
df['DayName'] = df['end timestamp'].dt.weekday_name
df['Fare'] = df['Fare'].str.strip('$').apply(float)
df['Tips'] = df['Tips'].str.strip('$').apply(float)
df['Tolls'] = df['Tolls'].str.strip('$').apply(float)
df['Extras'] = df['Extras'].str.strip('$').apply(float)
df['Trip Total'] = df['Trip Total'].str.strip('$').apply(float)

# %%
df.loc[df['Payment Type'] == 'Cash', 'Tips'] = 0.0

# %%
df.loc[df['Payment Type'] == 'Cash', 'Payment Type'] = 1
df.loc[df['Payment Type'] == 'Credit Card', 'Payment Type'] = 0
df.loc[df['Payment Type'] == 'Unknown', 'Payment Type'] = 2
df.loc[df['Payment Type'] == 'Dispute', 'Payment Type'] = 3
df.loc[df['Payment Type'] == 'No Charge', 'Payment Type'] = 4

# %%
df = df[(df['Fare']>3.25) & (df['Fare']<1000)]  #Assuming min fare = 3.25 and discurding fares more than 1000
df = df[df['Trip Seconds'] <= (12*60*60)]

del df['Trip ID']
del df['Trip Start Timestamp']
del df['Trip End Timestamp']
del df['Pickup O\'Hare Community Area']
del df['Pickup Centroid Location']

# %%
df = df.drop(df.columns[[19]], axis=1)

# %%
#modifications to obtain a smaller dataset (select only those rows with credit card payments and then subset interesting columns only

# %%
df = df[df['Payment Type'] == 0]
#extracting only credit card payment types

# %%
df['hour'] = df['start timestamp'].dt.hour
#extracting the hour of the day when each ride took place

# %%
df['year'] = df['start timestamp'].dt.year
#extracting the year

# %%
df1 = df [['Trip Seconds','Trip Miles', 'Pickup Community Area','Dropoff Community Area',
           'Fare','Tips','Company','month','DayName','hour','Extras','Tolls','Trip Total']]

# %%
import os, json, requests, pickle
from scipy.stats import skew
from shapely.geometry import Point,Polygon,MultiPoint,MultiPolygon
from scipy.stats import ttest_ind, f_oneway, lognorm, levy, skew, chisquare
#import scipy.stats as st
from sklearn.preprocessing import normalize, scale
#from tabulate import tabulate

# %%
#trip distance histogram

fig,ax = plt.subplots(1,1,figsize = (10,5)) 
v = df1['Trip Miles']
v[~((v-v.median()).abs()>3*v.std())].hist(bins=50, edgecolor='black') #exclude any data point located 3 std dev from the mean 
ax.set_xlabel('Trip Distance (miles)')
ax.set_ylabel('Count')
ax.set_title('Trip Distance Histogram')
plt.show()

# %% [markdown]
# The Trip Distance is asymmetrically distributed. It is skewed to the right and it has a median smaller than its mean and both smaller than the standard deviation. The skewness is due to the fact that the variable has a lower boundary of 0. The distance can’t be negative. This distribution has a structure of a lognormal distribution.
#
# The hypothesis: The trips are not random. If there were random, we would have a (symmetric) Gaussian distribution. The non-zero autocorrelation may be related the fact that people taking ride are pushed by a common cause, for instance, people rushing to work.

# %%
#Predictive model building  Making a new column for the Tip Percentage
df1['tip_percent'] = 100*df1.Tips/df1.Fare

#remove all tips greater than 100%
df1 = df1[df1['tip_percent'] < 100]

#replace the NaN Company values with 'unknown'
df1.Company.fillna('unknown',inplace =True)

# %%
print("Summary: Tip percentage\n",df1.tip_percent.describe())

# %%
#Comapare Tips for all of Chicago vs only O'hare-76 vs only Downtown-Loop-32

v1 = df1[(df1['Dropoff Community Area']==76) & (df1.tip_percent>0)].tip_percent
v2 = df1[(df1['Dropoff Community Area']!=76) & (df1.tip_percent>0)].tip_percent

bins = np.histogram(v1,bins=10)[1]
h1 = np.histogram(v1,bins=bins)
h2 = np.histogram(v2,bins=bins)

# generate the plot
# First suplot: visualize all data with outliers
fig,ax = plt.subplots(1,1,figsize=(10,5))
w = .4*(bins[1]-bins[0])
ax.bar(bins[:-1],h1[0],width=w,color='r')
ax.bar(bins[:-1]+w,h2[0],width=w,color='y')
ax.set_yscale('log')
ax.set_xlabel('Tip (%)')
ax.set_ylabel('Count')
ax.set_title('Tip')
ax.legend(['O-Hare','Rest of Chicago'],title='Origin')
plt.show()
print('t-test results:', ttest_ind(v1,v2,equal_var=False))
# Out:
# t-test results: Ttest_indResult(statistic=-142.27331322012415, pvalue=0.0)

# %% [markdown]
# The two distributions look the same except towards the end however the t-test results in a zero p-value to imply that the two groups are different at 95% level of condidence

# %%
#Distribution of Tips
fig,ax=plt.subplots(1,1,figsize=(15,10))

data1 = df1[df1.tip_percent>0]
df1.tip_percent.hist(bins = 20,color ='r',edgecolor='black')
ax.set_xlabel('Tip (%)')
ax.set_title('Distribution of Tip (%)')
ax.set_ylabel('Count')
plt.show()

# %%
#Majority of Tips vary between 15 to 25 percent which is the general customary rate for Chicago Taxis

# %%
import seaborn as sns

# %%
#correlation heatmap
continuous_variables=['Trip Seconds','Trip Miles','Fare','Tips','Trip Total','tip_percent']
cor_mat = df1[continuous_variables].corr()
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(cor_mat, mask=np.zeros_like(cor_mat, dtype=np.bool))
plt.show()

# %%
sns.pairplot(df1[continuous_variables])

# %% [markdown]
# As seen above there is almost no observable correlation between tip_percent and other continuous variables. Let us check tip_percent scatters against the three key variables. Therefore Random forest regression is used instead of regression

# %%
df1.tip_percent = round(df1.tip_percent,2)

# %%
#However if if check against Tips, then we find multiple correlated continuous varaibles

# %%
df1.head()
# Out:
#     Trip Seconds  Trip Miles  Pickup Community Area  Dropoff Community Area  \
# 3          600.0         1.5                    6.0                     6.0
# 6          780.0         1.4                   28.0                     8.0
# 10         540.0         2.3                   77.0                     3.0
# 13         240.0         0.0                    8.0                     8.0
# 15        2760.0        15.6                    6.0                    76.0
#
#      Fare   Tips                    Company  month    DayName  hour  Extras  \
# 3    7.75   3.00  Dispatch Taxi Affiliation      1     Friday    23     1.0
# 6    8.50   3.00                    unknown      1     Friday    16     0.0
# 10   9.00   0.00                    unknown      1  Wednesday     6     0.0
# 13   5.75   2.00  Taxi Affiliation Services      1   Saturday     0     1.0
# 15  40.75  10.15    Choice Taxi Association      1    Tuesday     7     0.0
#
#     Tolls  Trip Total  tip_percent
# ...

# %% [markdown]
# #Classification Problem
# Creating data for the classification problem...here we want to predict whether a passenger will tip the driver for a trip or not.
# Since the data contains very few number of 0 tips hence undersampling is performed to ensure that substantial no. of zeros remain in the new data.

# %%
df2 =df1 #df2 is temporary database

# %%
Cindex = pd.factorize(df2.Company)
df2.Company = pd.factorize(df2.Company)[0]

Dindex = pd.factorize(df2.DayName)
df2.DayName = pd.factorize(df2.DayName)[0]

# %%
df2.tip_percent[(df2['tip_percent'] > 0)] = 1
df2.tip_percent[(df2['tip_percent'] == 0)] = 0

# %%
df2.drop(['Trip Total'], axis = 1, inplace = True)

# %%
#all features normalized
import pandas as pd
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df2)
df2 = pd.DataFrame(np_scaled)

# %%
#split into test-train

# %%
#divide into train and test 80-20
from sklearn.cross_validation import train_test_split
train, test = train_test_split(df2, test_size=0.8)

# %%
#undersampling train dataset to 75-25 sample
df3 = train[train.iloc[:,8] == 0] #dataset df2 contains only '0' tip observations
df4 = train[train.iloc[:,8] != 0].sample(n = 3*df3.shape[0]) #dataset containing NO '0' tip obs samples to a size 1 times no of rows of df2
trainu = pd.concat([df3,df4]).sample(frac =1).reset_index(drop = True)

# %%
Train_feature = trainu.iloc[:,0:8]
Train_response = trainu.iloc[:,8]

# %%
Test_feature = test.iloc[:,0:8]
Test_response = test.iloc[:,8]

# %% [markdown]
# #Model Fitting
# Comaparing results of Logistic Regression, Linear Discriminant Analysis and Random Forest

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier


#############################
## Logistic Regression ##
#############################
LR = LogisticRegression()
LR.fit(Train_feature, Train_response)


######################################
## Linear Discriminant Analysis ##
######################################
LDA = LinearDiscriminantAnalysis()
LDA.fit(Train_feature, Train_response)


######################################
## Random Forest ##
######################################
RF = RandomForestClassifier(n_estimators =5)
RF.fit(Train_feature, Train_response)

# %% [markdown]
# #Predictions

# %%
from sklearn.metrics import accuracy_score

#############################
## Logistic Regression ##
#############################
pred_lr = LR.predict(Test_feature)
probs_lr =LR.predict_proba(Test_feature)
accuracy_lr = accuracy_score(Test_response, pred_lr)

######################################
## Linear Discriminant Analysis ##
######################################
pred_lda = LDA.predict(Test_feature)                       
probs_lda = LDA.predict_proba(Test_feature)               
accuracy_lda = accuracy_score(Test_response, pred_lda)   


######################################
## Random Forest ##
######################################
pred_rf = RF.predict(Test_feature)                       
probs_rf = RF.predict_proba(Test_feature)                 
accuracy_rf = accuracy_score(Test_response, pred_rf)

# %%
print(accuracy_lr,accuracy_lda, accuracy_rf)

# %% [markdown]
# # Tuned Random Forest generation
# The next objective is to tune the random forest hyperparameters to achieve max prediction accuracy on test data
# Parameters to vary:
# N_estimators = max no of trees, Number of features to consider at every split, Maximum number of levels in tree, Minimum number of samples required to split a node, Minimum number of samples required at each leaf node, Method of selecting samples for training each tree, Tuning performed on over 4000 settings

# %%
# the next objective is to tune the random forest hyperparameters to achieve max prediction accuracy on test data

#parameters to vary: n_estimators = max no of trees,
# Number of features to consider at every split
# Maximum number of levels in tree
# Minimum number of samples required to split a node
# Minimum number of samples required at each leaf node
# Method of selecting samples for training each tree
# Tuning performed on over 4000 settings

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state = 42)
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(rf.get_params())

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
pprint(random_grid)

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
rf_random.fit(Train_features, Train_responses)

# %%
rf_random.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 100,
#  'max_features': 'auto',
#  'min_samples_leaf': 4,
#  'min_samples_split': 5,
#  'n_estimators': 1000}

# %%
#tuned random forest with new parameters
RFtuned = RandomForestClassifier(bootstrap =True,  max_depth = 100, min_samples_leaf= 4, min_samples_split = 5, n_estimators = 1000)
RFtuned.fit(Train_feature, Train_response)

# %%
pred_rft = RFtuned.predict(Test_feature)                       
probs_rft = RFtuned.predict_proba(Test_feature)                 
accuracy_rft = accuracy_score(Test_response, pred_rft)

# %% [markdown]
# #Receiver Operating Characteristics Curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from sklearn import metrics
#plt.figure()

#plt.subplot(2,5,1)
fpr_lda,tpr_lda, threshold_lda = metrics.roc_curve(Test_response,probs_lda[:,1],pos_label =True)
fpr_lr,tpr_lr, threshold_lr = metrics.roc_curve(Test_response,probs_lr[:,1],pos_label =True)
fpr_rf,tpr_rf, threshold_rf = metrics.roc_curve(Test_response,probs_rf[:,1],pos_label =True)
fpr_rft,tpr_rft, threshold_rft = metrics.roc_curve(Test_response,probs_rft[:,1],pos_label =True)
#fpr_svm,tpr_svm, threshold_svm = metrics.roc_curve(Test_responses,probs_svm[:,1],pos_label =True)

roc_auc_mnb_title = auc(fpr_mnb_title,tpr_mnb_title)
plt.title('Receiver Operating Characteristic Curve')
plt.plot(fpr_rf, tpr_rf,color = 'r')
plt.plot(fpr_lda, tpr_lda, color = 'c' )
plt.plot(fpr_lr, tpr_lr, color = 'm')
plt.plot(fpr_rft, tpr_rft, color = 'y')
#plt.plot(fpr_svm, tpr_svm, color = 'b')


# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #Confusion Matrix for Tuned Random Forest

# %%
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(Test_response, pred_rft))
sns.heatmap(cm, annot=True,fmt='g')

# %% [markdown]
# #Feature Imporatance for Tuned Random Forest

# %%
importances = RFtuned.feature_importances_
indices = np.argsort(importances)[::-1]
std = np.std([tree.feature_importances_ for tree in RFtuned.estimators_], axis=0)
plt.bar(range(Train_feature.shape[1]), importances[indices],color="r", yerr=std[indices], align="center")
plt.xticks(range(Train_feature.shape[1]), indices)
# Out:
# ([<matplotlib.axis.XTick at 0x7fdf093659e8>,
# ...
#  <a list of 8 Text xticklabel objects>)

# %% [markdown]
# #Regression modelling for predicting Fare amount

# %%
#Data Preprocessing

# %%
dfr =df1 #dfr is temporary database

# %%
dfr.drop(['tip_percent'], axis = 1, inplace = True)

# %%
Dindex = pd.factorize(dfr.DayName)
dfr.DayName = pd.factorize(dfr.DayName)[0]

# %%
#all features normalized
import pandas as pd
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(dfr)
dfr = pd.DataFrame(np_scaled)

# %%
#split into test-train 
responses = dfr.iloc[:,4]

# %%
#divide into train and test 80-20
from sklearn.cross_validation import train_test_split
features = dfr.drop(dfr.columns[4], axis=1)

# %%
Train_features, Test_features, Train_responses, Test_responses = train_test_split(
    features, responses, test_size=0.2, random_state=42)

# %% [markdown]
# Comparing Linear Regression and Random Forest for Predicting Fare amount

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor



rf = RandomForestRegressor(n_estimators=100, oob_score=True, random_state=0)
rf.fit(Train_features, Train_responses)

lm = LinearRegression()
lm.fit(Train_features, Train_responses)

# %%
from sklearn.metrics import r2_score
#from scipy.stats import spearmanr, pearsonr
predicted_train = rf.predict(Train_features)
predicted_test = rf.predict(Test_features)
r2_score(Test_responses, predicted_test)

# %%
from sklearn.metrics import r2_score
from scipy.stats import spearmanr, pearsonr
predicted_train_lm = lm.predict(Train_features)
predicted_test_lm = lm.predict(Test_features)
r2_score(Test_responses, predicted_test_lm)

# %% [markdown]
# #Random Forest Scatter Plot
#
# Test Responses on the x-axis vs predicted values on the y-axis

# %%
plt.scatter(Test_responses, predicted_test)

# %% [markdown]
# #Random Forest Feature Importance for predicting Fare

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
std = np.std([tree.feature_importances_ for tree in rf.estimators_], axis=0)
plt.bar(range(Train_features.shape[1]), importances[indices],color="r", yerr=std[indices], align="center")
plt.xticks(range(Train_features.shape[1]), indices)
# Out:
# ([<matplotlib.axis.XTick at 0x7f497e29e240>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# #Scatter plot for Linear Regression
#
# Test Responses on the x-axis vs predicted values on the y-axis

# %%
plt.scatter(Test_responses, predicted_test_lm)

# %% [markdown]
# #Linear Regression model coefficients

# %%
lm.coef_
# Out:
# array([ 4.67890220e-01,  2.90438073e-01,  2.14466838e-02,  1.52626823e-02,
#        -2.77555756e-17,  1.50094008e-03, -2.63640628e-03])
